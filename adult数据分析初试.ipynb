# %%
# %matplotlib inline

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

path="E:/adult.txt"
df=pd.read_csv(path,names=list("ABCDEFGHIJKLMNO"))

# %%
labels='<30','30-40','40-50','>50'
colors=['gold','blue','red','green']
explode=(0,0.1,0,0)

plt.pie([4804,5684,4580,3348],explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=False,startangle=90)
plt.axis('equal')
plt.show()

# %%
df.B.value_counts().plot.bar()

# %%
df.head(10)
# Out:
#     A                  B       C              D   E                    F  \
# 0  25            Private  226802           11th   7        Never-married
# 1  38            Private   89814        HS-grad   9   Married-civ-spouse
# 2  28          Local-gov  336951     Assoc-acdm  12   Married-civ-spouse
# 3  44            Private  160323   Some-college  10   Married-civ-spouse
# 4  18                  ?  103497   Some-college  10        Never-married
# 5  34            Private  198693           10th   6        Never-married
# 6  29                  ?  227026        HS-grad   9        Never-married
# 7  63   Self-emp-not-inc  104626    Prof-school  15   Married-civ-spouse
# 8  24            Private  369667   Some-college  10        Never-married
# 9  55            Private  104996        7th-8th   4   Married-civ-spouse
#
#                     G               H       I        J     K  L   M  \
# 0   Machine-op-inspct       Own-child   Black     Male     0  0  40
# 1     Farming-fishing         Husband   White     Male     0  0  50
# 2     Protective-serv         Husband   White     Male     0  0  40
# 3   Machine-op-inspct         Husband   Black     Male  7688  0  40
# 4                   ?       Own-child   White   Female     0  0  30
# 5       Other-service   Not-in-family   White     Male     0  0  30
# 6                   ?       Unmarried   Black     Male     0  0  40
# 7      Prof-specialty         Husband   White     Male  3103  0  32
# 8       Other-service       Unmarried   White   Female     0  0  40
# 9        Craft-repair         Husband   White     Male     0  0  10
#
#                 N        O
# 0   United-States   <=50K.
# 1   United-States   <=50K.
# 2   United-States    >50K.
# 3   United-States    >50K.
# 4   United-States   <=50K.
# 5   United-States   <=50K.
# 6   United-States   <=50K.
# 7   United-States    >50K.
# 8   United-States   <=50K.
# 9   United-States   <=50K.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16281 entries, 25 to 35
# Data columns (total 14 columns):
# A    16281 non-null object
# B    16281 non-null int64
# C    16281 non-null object
# D    16281 non-null int64
# E    16281 non-null object
# F    16281 non-null object
# G    16281 non-null object
# H    16281 non-null object
# I    16281 non-null object
# J    16281 non-null int64
# K    16281 non-null int64
# L    16281 non-null int64
# M    16281 non-null object
# N    16281 non-null object
# dtypes: int64(5), object(9)
# memory usage: 2.2+ MB

# %%
df.isnull.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-bdc1d976d3a6> in <module>()
# ----> 1 df.isnull.sum()
#
# AttributeError: 'function' object has no attribute 'sum'

# %%
df.isnull().sum()
# Out:
# A    0
# B    0
# C    0
# D    0
# E    0
# F    0
# G    0
# H    0
# I    0
# J    0
# K    0
# L    0
# M    0
# N    0
# O    0
# dtype: int64

# %%
df.groupby('J').B.mean()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-48-b2d93435197d> in <module>()
# ----> 1 df.groupby('J').B.mean()
#
# e:\anaconda2\lib\site-packages\pandas\core\groupby.pyc in mean(self, *args, **kwargs)
#    1126         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1127         try:
# -> 1128             return self._cython_agg_general('mean', **kwargs)
#    1129         except GroupByError:
#    1130             raise
#
# e:\anaconda2\lib\site-packages\pandas\core\groupby.pyc in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     925
#     926         if len(output) == 0:
# --> 927             raise DataError('No numeric types to aggregate')
#     928
#     929         return self._wrap_aggregated_output(output, names)
#
# DataError: No numeric types to aggregate

# %%
df=df.set_index('E')
df.sort_index(ascending=True)
# Out:
#      A                  B       C           D                       F  \
# E
# 1   37   Self-emp-not-inc  227253   Preschool      Married-civ-spouse
# 1   43   Self-emp-not-inc  245056   Preschool      Married-civ-spouse
# 1   50            Private  193081   Preschool           Never-married
# 1   61            Private  194804   Preschool               Separated
# 1   19            Private  277695   Preschool           Never-married
# 1   22            Private  267412   Preschool           Never-married
# 1   30            Private   90308   Preschool           Never-married
# 1   24            Private  403107   Preschool           Never-married
# 1   33            Private  295591   Preschool           Never-married
# 1   21            Private  243368   Preschool           Never-married
# 1   53            Private  308082   Preschool           Never-married
# 1   51            Private  186299   Preschool           Never-married
# 1   29                  ?  565769   Preschool           Never-married
# 1   50            Private  330543   Preschool      Married-civ-spouse
# 1   64            Private   86837   Preschool      Married-civ-spouse
# 1   21            Private  243368   Preschool           Never-married
# 1   54                  ?   99208   Preschool      Married-civ-spouse
# 1   77   Self-emp-not-inc  161552   Preschool                 Widowed
# 1   21                  ?  436431   Preschool      Married-civ-spouse
# 1   60   Self-emp-not-inc  269485   Preschool                Divorced
# 1   60                  ?  225894   Preschool                 Widowed
# 1   35            Private  290498   Preschool      Married-civ-spouse
# 1   61   Self-emp-not-inc  243019   Preschool      Married-civ-spouse
# 1   47            Private   98044   Preschool           Never-married
# 1   47            Private  235431   Preschool           Never-married
# 1   37            Private  216845   Preschool      Married-civ-spouse
# 1   28            Private  203784   Preschool           Never-married
# 1   50            Private  176773   Preschool      Married-civ-spouse
# 1   31            Private   25610   Preschool           Never-married
# 1   57                  ?  274680   Preschool               Separated
# ..  ..                ...     ...         ...                     ...
# 16  42            Private  167174   Doctorate      Married-civ-spouse
# 16  62            Private   93997   Doctorate      Married-civ-spouse
# 16  42          State-gov  218948   Doctorate                Divorced
# 16  48        Federal-gov   42972   Doctorate      Married-civ-spouse
# 16  49            Private  132476   Doctorate                Divorced
# 16  41   Self-emp-not-inc   49156   Doctorate           Never-married
# 16  48            Private  366089   Doctorate      Married-civ-spouse
# 16  27            Private  189565   Doctorate      Married-civ-spouse
# 16  48            Private  102359   Doctorate      Married-civ-spouse
# 16  42   Self-emp-not-inc  344624   Doctorate           Never-married
# 16  41            Private  177989   Doctorate      Married-civ-spouse
# 16  44          State-gov   26880   Doctorate                Divorced
# 16  42       Self-emp-inc  100793   Doctorate      Married-civ-spouse
# 16  58   Self-emp-not-inc  112076   Doctorate       Married-AF-spouse
# 16  52        Federal-gov  297906   Doctorate      Married-civ-spouse
# 16  44            Private  146659   Doctorate      Married-civ-spouse
# 16  62   Self-emp-not-inc  116626   Doctorate                 Widowed
# 16  27          State-gov  301302   Doctorate   Married-spouse-absent
# 16  36          State-gov  230329   Doctorate      Married-civ-spouse
# 16  53       Self-emp-inc  200400   Doctorate                Divorced
# 16  50       Self-emp-inc   68898   Doctorate      Married-civ-spouse
# 16  46            Private  344415   Doctorate      Married-civ-spouse
# 16  35          State-gov   37314   Doctorate           Never-married
# 16  58          State-gov   21838   Doctorate      Married-civ-spouse
# 16  34            Private   87535   Doctorate           Never-married
# 16  40            Private   85019   Doctorate      Married-civ-spouse
# 16  56          State-gov  165867   Doctorate      Married-civ-spouse
# 16  47            Private  121253   Doctorate                Divorced
# 16  44            Private  321824   Doctorate      Married-civ-spouse
# 16  77          State-gov  267799   Doctorate   Married-spouse-absent
#
#                      G                H                    I        J      K  \
# E
# 1                Sales          Husband                White     Male      0
# 1     Transport-moving          Husband                Black     Male      0
# 1        Other-service    Not-in-family                Black   Female      0
# 1     Transport-moving    Not-in-family                Black     Male  14344
# 1      Farming-fishing    Not-in-family                White     Male      0
# 1        Other-service        Own-child                Black   Female    594
# 1        Other-service        Unmarried                White     Male      0
# 1         Adm-clerical    Not-in-family                White     Male      0
# 1      Farming-fishing    Not-in-family                White     Male      0
# 1      Farming-fishing    Not-in-family                White     Male      0
# 1        Other-service    Not-in-family                White   Female      0
# 1    Machine-op-inspct    Not-in-family                White     Male      0
# 1                    ?    Not-in-family                Black     Male      0
# 1        Other-service          Husband                White     Male      0
# 1    Handlers-cleaners          Husband   Asian-Pac-Islander     Male      0
# 1      Farming-fishing    Not-in-family                White     Male      0
# 1                    ?          Husband                White     Male      0
# 1      Exec-managerial    Not-in-family                White   Female      0
# 1                    ?   Other-relative                White   Female      0
# 1        Other-service        Unmarried                White   Female      0
# 1                    ?    Not-in-family                White   Female      0
# 1         Craft-repair          Husband                White     Male      0
# 1         Craft-repair          Husband                White     Male      0
# 1        Other-service    Not-in-family                White     Male      0
# 1                Sales        Unmarried                Black   Female      0
# 1      Farming-fishing          Husband                White     Male      0
# 1      Farming-fishing    Not-in-family                White     Male      0
# 1      Farming-fishing          Husband                Black     Male      0
# 1    Handlers-cleaners    Not-in-family   Amer-Indian-Eskimo     Male      0
# 1                    ?    Not-in-family                White     Male      0
# ..                 ...              ...                  ...      ...    ...
# 16      Prof-specialty          Husband   Asian-Pac-Islander     Male      0
# 16     Exec-managerial          Husband                White     Male  99999
# 16      Prof-specialty        Unmarried                Black   Female      0
# 16      Prof-specialty             Wife                White   Female      0
# 16        Tech-support        Unmarried                White     Male   7430
# 16      Prof-specialty    Not-in-family                White     Male      0
# 16      Prof-specialty          Husband                White     Male      0
# 16      Prof-specialty          Husband                White     Male      0
# 16      Prof-specialty          Husband                White     Male      0
# 16      Prof-specialty    Not-in-family                White     Male      0
# 16      Prof-specialty          Husband                White     Male      0
# 16      Prof-specialty    Not-in-family                White   Female      0
# 16      Prof-specialty          Husband                White     Male      0
# 16     Exec-managerial             Wife                White   Female      0
# 16      Prof-specialty          Husband   Asian-Pac-Islander     Male      0
# 16      Prof-specialty          Husband                White     Male      0
# 16     Exec-managerial    Not-in-family                White   Female      0
# 16        Tech-support    Not-in-family                White     Male      0
# 16      Prof-specialty          Husband                White     Male   7298
# 16     Exec-managerial    Not-in-family                White     Male      0
# 16     Exec-managerial          Husband                White     Male   7688
# 16      Prof-specialty          Husband                White     Male      0
# 16      Prof-specialty    Not-in-family                White     Male      0
# 16      Prof-specialty          Husband                White     Male   7688
# 16     Exec-managerial    Not-in-family                White   Female      0
# 16      Prof-specialty          Husband   Asian-Pac-Islander     Male      0
# 16      Prof-specialty          Husband                White     Male      0
# 16      Prof-specialty        Unmarried                White   Female      0
# 16      Prof-specialty          Husband                White     Male      0
# 16      Prof-specialty    Not-in-family                White     Male      0
#
#        L   M               N        O
# E
# 1      0  30          Mexico   <=50K.
# 1      0  40           Haiti   <=50K.
# 1      0  40           Haiti   <=50K.
# 1      0  40   United-States    >50K.
# 1      0  50          Mexico   <=50K.
# 1      0  20         Jamaica   <=50K.
# 1      0  28     El-Salvador   <=50K.
# 1      0  40          Mexico   <=50K.
# 1      0  40          Mexico   <=50K.
# 1      0  50          Mexico   <=50K.
# 1      0  15     El-Salvador   <=50K.
# 1      0  30   United-States   <=50K.
# 1      0  40           South   <=50K.
# 1      0  40          Mexico   <=50K.
# 1      0  40     Philippines   <=50K.
# 1      0  25          Mexico   <=50K.
# 1      0  16   United-States   <=50K.
# 1      0  60   United-States   <=50K.
# 1      0  40          Mexico   <=50K.
# 1      0  40          Mexico   <=50K.
# 1      0  40       Guatemala   <=50K.
# 1      0  38          Mexico   <=50K.
# 1      0  40   United-States   <=50K.
# 1      0  25     El-Salvador   <=50K.
# 1      0  40           Haiti   <=50K.
# 1      0  40          Mexico   <=50K.
# 1      0  38          Mexico   <=50K.
# 1      0  40           Haiti   <=50K.
# 1      0  25   United-States   <=50K.
# 1      0  40   United-States   <=50K.
# ..   ...  ..             ...      ...
# 16     0  50           China    >50K.
# 16     0  40   United-States    >50K.
# 16     0  36         Jamaica   <=50K.
# 16     0  40   United-States    >50K.
# 16     0  40   United-States    >50K.
# 16     0  30   United-States   <=50K.
# 16     0  45   United-States    >50K.
# 16     0  40   United-States    >50K.
# 16     0  60   United-States    >50K.
# 16     0  99   United-States    >50K.
# 16  2051  60   United-States   <=50K.
# 16  1092  40   United-States   <=50K.
# 16     0  41   United-States    >50K.
# 16  1485  35   United-States    >50K.
# 16     0  40               ?    >50K.
# 16     0  50   United-States   <=50K.
# 16     0  40   United-States    >50K.
# 16     0  20               ?   <=50K.
# 16     0  40   United-States    >50K.
# 16     0  60   United-States    >50K.
# 16     0  60   United-States    >50K.
# 16     0  40   United-States    >50K.
# 16     0  55   United-States   <=50K.
# 16     0  50   United-States    >50K.
# 16     0  40   United-States   <=50K.
# 16     0  45               ?    >50K.
# 16     0  40   United-States    >50K.
# 16     0  29   United-States   <=50K.
# 16     0  20   United-States   <=50K.
# 16     0   4   United-States    >50K.
#
# [16281 rows x 14 columns]

# %%
plt.scatter(df.E,df.K)
plt.show()

# %%
df.I.nunique()
# Out:
# 5

# %%
white=(df['I']=='White').count()
black=(df.I=='Black').count()
api=(df.I=='Asian-Pac-Islander').count()
aie=(df.I=='Amer-Indian-Eskimo').count()
other=(df.I=='Other').count()


labels='white','black','api','aie','other'
sizes=[white,black,api,aie,other]
colors=['gold','blue','red','yellow','green']
explode=(0,0.1,0,0,0)

plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=False,startangle=90)
plt.axis('equal')
plt.show()

# %%
df.index
# Out:
# RangeIndex(start=0, stop=16281, step=1)

# %%
df[df['I']='Black'].head()
# Out:
#   File "<ipython-input-21-fdff47954905>", line 1
#     df[df['I']='Black'].head()
#               ^
# SyntaxError: invalid syntax

# %%
df.I="Black"

# %%
# Out:
#         A                  B       C              D   E                    F  \
# 0      25            Private  226802           11th   7        Never-married
# 1      38            Private   89814        HS-grad   9   Married-civ-spouse
# 2      28          Local-gov  336951     Assoc-acdm  12   Married-civ-spouse
# 3      44            Private  160323   Some-college  10   Married-civ-spouse
# 4      18                  ?  103497   Some-college  10        Never-married
# 5      34            Private  198693           10th   6        Never-married
# 6      29                  ?  227026        HS-grad   9        Never-married
# 7      63   Self-emp-not-inc  104626    Prof-school  15   Married-civ-spouse
# 8      24            Private  369667   Some-college  10        Never-married
# 9      55            Private  104996        7th-8th   4   Married-civ-spouse
# 10     65            Private  184454        HS-grad   9   Married-civ-spouse
# 11     36        Federal-gov  212465      Bachelors  13   Married-civ-spouse
# 12     26            Private   82091        HS-grad   9        Never-married
# 13     58                  ?  299831        HS-grad   9   Married-civ-spouse
# 14     48            Private  279724        HS-grad   9   Married-civ-spouse
# 15     43            Private  346189        Masters  14   Married-civ-spouse
# 16     20          State-gov  444554   Some-college  10        Never-married
# 17     43            Private  128354        HS-grad   9   Married-civ-spouse
# 18     37            Private   60548        HS-grad   9              Widowed
# 19     40            Private   85019      Doctorate  16   Married-civ-spouse
# 20     34            Private  107914      Bachelors  13   Married-civ-spouse
# 21     34            Private  238588   Some-college  10        Never-married
# 22     72                  ?  132015        7th-8th   4             Divorced
# 23     25            Private  220931      Bachelors  13        Never-married
# 24     25            Private  205947      Bachelors  13   Married-civ-spouse
# 25     45   Self-emp-not-inc  432824        HS-grad   9   Married-civ-spouse
# 26     22            Private  236427        HS-grad   9        Never-married
# 27     23            Private  134446        HS-grad   9            Separated
# 28     54            Private   99516        HS-grad   9   Married-civ-spouse
# 29     32   Self-emp-not-inc  109282   Some-college  10        Never-married
# ...    ..                ...     ...            ...  ..                  ...
# 16251  81                  ?   26711      Assoc-voc  11   Married-civ-spouse
# 16252  60            Private  117909      Assoc-voc  11   Married-civ-spouse
# 16253  39            Private  229647      Bachelors  13        Never-married
# 16254  38            Private  149347        Masters  14   Married-civ-spouse
# 16255  43          Local-gov   23157        Masters  14   Married-civ-spouse
# 16256  23            Private   93977        HS-grad   9        Never-married
# 16257  73       Self-emp-inc  159691   Some-college  10             Divorced
# 16258  35            Private  176967   Some-college  10   Married-civ-spouse
# 16259  66            Private  344436        HS-grad   9              Widowed
# 16260  27            Private  430340   Some-college  10        Never-married
# 16261  40            Private  202168    Prof-school  15   Married-civ-spouse
# 16262  51            Private   82720        HS-grad   9   Married-civ-spouse
# 16263  22            Private  269623   Some-college  10        Never-married
# 16264  64   Self-emp-not-inc  136405        HS-grad   9              Widowed
# 16265  50          Local-gov  139347        Masters  14   Married-civ-spouse
# 16266  55            Private  224655        HS-grad   9            Separated
# 16267  38            Private  247547      Assoc-voc  11        Never-married
# 16268  58            Private  292710     Assoc-acdm  12             Divorced
# 16269  32            Private  173449        HS-grad   9   Married-civ-spouse
# 16270  48            Private  285570        HS-grad   9   Married-civ-spouse
# 16271  61            Private   89686        HS-grad   9   Married-civ-spouse
# 16272  31            Private  440129        HS-grad   9   Married-civ-spouse
# 16273  25            Private  350977        HS-grad   9        Never-married
# 16274  48          Local-gov  349230        Masters  14             Divorced
# 16275  33            Private  245211      Bachelors  13        Never-married
# 16276  39            Private  215419      Bachelors  13             Divorced
# 16277  64                  ?  321403        HS-grad   9              Widowed
# 16278  38            Private  374983      Bachelors  13   Married-civ-spouse
# 16279  44            Private   83891      Bachelors  13             Divorced
# 16280  35       Self-emp-inc  182148      Bachelors  13   Married-civ-spouse
#
#                         G                H                    I        J  \
# 0       Machine-op-inspct        Own-child                Black     Male
# 1         Farming-fishing          Husband                White     Male
# 2         Protective-serv          Husband                White     Male
# 3       Machine-op-inspct          Husband                Black     Male
# 4                       ?        Own-child                White   Female
# 5           Other-service    Not-in-family                White     Male
# 6                       ?        Unmarried                Black     Male
# 7          Prof-specialty          Husband                White     Male
# 8           Other-service        Unmarried                White   Female
# 9            Craft-repair          Husband                White     Male
# 10      Machine-op-inspct          Husband                White     Male
# 11           Adm-clerical          Husband                White     Male
# 12           Adm-clerical    Not-in-family                White   Female
# 13                      ?          Husband                White     Male
# 14      Machine-op-inspct          Husband                White     Male
# 15        Exec-managerial          Husband                White     Male
# 16          Other-service        Own-child                White     Male
# 17           Adm-clerical             Wife                White   Female
# 18      Machine-op-inspct        Unmarried                White   Female
# 19         Prof-specialty          Husband   Asian-Pac-Islander     Male
# 20           Tech-support          Husband                White     Male
# 21          Other-service        Own-child                Black   Female
# 22                      ?    Not-in-family                White   Female
# 23         Prof-specialty    Not-in-family                White     Male
# 24         Prof-specialty          Husband                White     Male
# 25           Craft-repair          Husband                White     Male
# 26           Adm-clerical        Own-child                White     Male
# 27      Machine-op-inspct        Unmarried                Black     Male
# 28           Craft-repair          Husband                White     Male
# 29         Prof-specialty    Not-in-family                White     Male
# ...                   ...              ...                  ...      ...
# 16251                   ?          Husband                White     Male
# 16252      Prof-specialty          Husband                White     Male
# 16253        Tech-support    Not-in-family                White   Female
# 16254      Prof-specialty          Husband                White     Male
# 16255     Exec-managerial          Husband                White     Male
# 16256   Machine-op-inspct        Own-child                White     Male
# 16257     Exec-managerial    Not-in-family                White   Female
# 16258     Protective-serv          Husband                White     Male
# 16259               Sales   Other-relative                White   Female
# 16260               Sales    Not-in-family                White   Female
# 16261      Prof-specialty          Husband                White     Male
# 16262        Craft-repair          Husband                White     Male
# 16263        Craft-repair        Own-child                White     Male
# 16264     Farming-fishing    Not-in-family                White     Male
# 16265      Prof-specialty             Wife                White   Female
# 16266     Priv-house-serv    Not-in-family                White   Female
# 16267        Adm-clerical        Unmarried                Black   Female
# 16268      Prof-specialty    Not-in-family                White     Male
# 16269   Handlers-cleaners          Husband                White     Male
# 16270        Adm-clerical          Husband                White     Male
# 16271               Sales          Husband                White     Male
# 16272        Craft-repair          Husband                White     Male
# 16273       Other-service        Own-child                White   Female
# 16274       Other-service    Not-in-family                White     Male
# 16275      Prof-specialty        Own-child                White     Male
# 16276      Prof-specialty    Not-in-family                White   Female
# 16277                   ?   Other-relative                Black     Male
# 16278      Prof-specialty          Husband                White     Male
# 16279        Adm-clerical        Own-child   Asian-Pac-Islander     Male
# 16280     Exec-managerial          Husband                White     Male
#
#            K     L   M               N        O
# 0          0     0  40   United-States   <=50K.
# 1          0     0  50   United-States   <=50K.
# 2          0     0  40   United-States    >50K.
# 3       7688     0  40   United-States    >50K.
# 4          0     0  30   United-States   <=50K.
# 5          0     0  30   United-States   <=50K.
# 6          0     0  40   United-States   <=50K.
# 7       3103     0  32   United-States    >50K.
# 8          0     0  40   United-States   <=50K.
# 9          0     0  10   United-States   <=50K.
# 10      6418     0  40   United-States    >50K.
# 11         0     0  40   United-States   <=50K.
# 12         0     0  39   United-States   <=50K.
# 13         0     0  35   United-States   <=50K.
# 14      3103     0  48   United-States    >50K.
# 15         0     0  50   United-States    >50K.
# 16         0     0  25   United-States   <=50K.
# 17         0     0  30   United-States   <=50K.
# 18         0     0  20   United-States   <=50K.
# 19         0     0  45               ?    >50K.
# 20         0     0  47   United-States    >50K.
# 21         0     0  35   United-States   <=50K.
# 22         0     0   6   United-States   <=50K.
# 23         0     0  43            Peru   <=50K.
# 24         0     0  40   United-States   <=50K.
# 25      7298     0  90   United-States    >50K.
# 26         0     0  20   United-States   <=50K.
# 27         0     0  54   United-States   <=50K.
# 28         0     0  35   United-States   <=50K.
# 29         0     0  60   United-States   <=50K.
# ...      ...   ...  ..             ...      ...
# 16251   2936     0  20   United-States   <=50K.
# 16252   7688     0  40   United-States    >50K.
# 16253      0  1669  40   United-States   <=50K.
# 16254      0     0  50   United-States    >50K.
# 16255      0  1902  50   United-States    >50K.
# 16256      0     0  40   United-States   <=50K.
# 16257      0     0  40   United-States   <=50K.
# 16258      0     0  40   United-States   <=50K.
# 16259      0     0   8   United-States   <=50K.
# 16260      0     0  45   United-States   <=50K.
# 16261  15024     0  55   United-States    >50K.
# 16262      0     0  40   United-States   <=50K.
# 16263      0     0  40   United-States   <=50K.
# 16264      0     0  32   United-States   <=50K.
# 16265      0     0  40               ?    >50K.
# 16266      0     0  32   United-States   <=50K.
# 16267      0     0  40   United-States   <=50K.
# 16268      0     0  36   United-States   <=50K.
# 16269      0     0  40   United-States   <=50K.
# 16270      0     0  40   United-States   <=50K.
# 16271      0     0  48   United-States   <=50K.
# 16272      0     0  40   United-States   <=50K.
# 16273      0     0  40   United-States   <=50K.
# 16274      0     0  40   United-States   <=50K.
# 16275      0     0  40   United-States   <=50K.
# 16276      0     0  36   United-States   <=50K.
# 16277      0     0  40   United-States   <=50K.
# 16278      0     0  50   United-States   <=50K.
# 16279   5455     0  40   United-States   <=50K.
# 16280      0     0  60   United-States    >50K.
#
# [16281 rows x 15 columns]

# %%
df.set_index('O')
# Out:
#           A                  B       C              D   E  \
# O
#  <=50K.  25            Private  226802           11th   7
#  <=50K.  38            Private   89814        HS-grad   9
#  >50K.   28          Local-gov  336951     Assoc-acdm  12
#  >50K.   44            Private  160323   Some-college  10
#  <=50K.  18                  ?  103497   Some-college  10
#  <=50K.  34            Private  198693           10th   6
#  <=50K.  29                  ?  227026        HS-grad   9
#  >50K.   63   Self-emp-not-inc  104626    Prof-school  15
#  <=50K.  24            Private  369667   Some-college  10
#  <=50K.  55            Private  104996        7th-8th   4
#  >50K.   65            Private  184454        HS-grad   9
#  <=50K.  36        Federal-gov  212465      Bachelors  13
#  <=50K.  26            Private   82091        HS-grad   9
#  <=50K.  58                  ?  299831        HS-grad   9
#  >50K.   48            Private  279724        HS-grad   9
#  >50K.   43            Private  346189        Masters  14
#  <=50K.  20          State-gov  444554   Some-college  10
#  <=50K.  43            Private  128354        HS-grad   9
#  <=50K.  37            Private   60548        HS-grad   9
#  >50K.   40            Private   85019      Doctorate  16
#  >50K.   34            Private  107914      Bachelors  13
#  <=50K.  34            Private  238588   Some-college  10
#  <=50K.  72                  ?  132015        7th-8th   4
#  <=50K.  25            Private  220931      Bachelors  13
#  <=50K.  25            Private  205947      Bachelors  13
#  >50K.   45   Self-emp-not-inc  432824        HS-grad   9
#  <=50K.  22            Private  236427        HS-grad   9
#  <=50K.  23            Private  134446        HS-grad   9
#  <=50K.  54            Private   99516        HS-grad   9
#  <=50K.  32   Self-emp-not-inc  109282   Some-college  10
# ...      ..                ...     ...            ...  ..
#  <=50K.  81                  ?   26711      Assoc-voc  11
#  >50K.   60            Private  117909      Assoc-voc  11
#  <=50K.  39            Private  229647      Bachelors  13
#  >50K.   38            Private  149347        Masters  14
#  >50K.   43          Local-gov   23157        Masters  14
#  <=50K.  23            Private   93977        HS-grad   9
#  <=50K.  73       Self-emp-inc  159691   Some-college  10
#  <=50K.  35            Private  176967   Some-college  10
#  <=50K.  66            Private  344436        HS-grad   9
#  <=50K.  27            Private  430340   Some-college  10
#  >50K.   40            Private  202168    Prof-school  15
#  <=50K.  51            Private   82720        HS-grad   9
#  <=50K.  22            Private  269623   Some-college  10
#  <=50K.  64   Self-emp-not-inc  136405        HS-grad   9
#  >50K.   50          Local-gov  139347        Masters  14
#  <=50K.  55            Private  224655        HS-grad   9
#  <=50K.  38            Private  247547      Assoc-voc  11
#  <=50K.  58            Private  292710     Assoc-acdm  12
#  <=50K.  32            Private  173449        HS-grad   9
#  <=50K.  48            Private  285570        HS-grad   9
#  <=50K.  61            Private   89686        HS-grad   9
#  <=50K.  31            Private  440129        HS-grad   9
#  <=50K.  25            Private  350977        HS-grad   9
#  <=50K.  48          Local-gov  349230        Masters  14
#  <=50K.  33            Private  245211      Bachelors  13
#  <=50K.  39            Private  215419      Bachelors  13
#  <=50K.  64                  ?  321403        HS-grad   9
#  <=50K.  38            Private  374983      Bachelors  13
#  <=50K.  44            Private   83891      Bachelors  13
#  >50K.   35       Self-emp-inc  182148      Bachelors  13
#
#                            F                   G                H  \
# O
#  <=50K.        Never-married   Machine-op-inspct        Own-child
#  <=50K.   Married-civ-spouse     Farming-fishing          Husband
#  >50K.    Married-civ-spouse     Protective-serv          Husband
#  >50K.    Married-civ-spouse   Machine-op-inspct          Husband
#  <=50K.        Never-married                   ?        Own-child
#  <=50K.        Never-married       Other-service    Not-in-family
#  <=50K.        Never-married                   ?        Unmarried
#  >50K.    Married-civ-spouse      Prof-specialty          Husband
#  <=50K.        Never-married       Other-service        Unmarried
#  <=50K.   Married-civ-spouse        Craft-repair          Husband
#  >50K.    Married-civ-spouse   Machine-op-inspct          Husband
#  <=50K.   Married-civ-spouse        Adm-clerical          Husband
#  <=50K.        Never-married        Adm-clerical    Not-in-family
#  <=50K.   Married-civ-spouse                   ?          Husband
#  >50K.    Married-civ-spouse   Machine-op-inspct          Husband
#  >50K.    Married-civ-spouse     Exec-managerial          Husband
#  <=50K.        Never-married       Other-service        Own-child
#  <=50K.   Married-civ-spouse        Adm-clerical             Wife
#  <=50K.              Widowed   Machine-op-inspct        Unmarried
#  >50K.    Married-civ-spouse      Prof-specialty          Husband
#  >50K.    Married-civ-spouse        Tech-support          Husband
#  <=50K.        Never-married       Other-service        Own-child
#  <=50K.             Divorced                   ?    Not-in-family
#  <=50K.        Never-married      Prof-specialty    Not-in-family
#  <=50K.   Married-civ-spouse      Prof-specialty          Husband
#  >50K.    Married-civ-spouse        Craft-repair          Husband
#  <=50K.        Never-married        Adm-clerical        Own-child
#  <=50K.            Separated   Machine-op-inspct        Unmarried
#  <=50K.   Married-civ-spouse        Craft-repair          Husband
#  <=50K.        Never-married      Prof-specialty    Not-in-family
# ...                      ...                 ...              ...
#  <=50K.   Married-civ-spouse                   ?          Husband
#  >50K.    Married-civ-spouse      Prof-specialty          Husband
#  <=50K.        Never-married        Tech-support    Not-in-family
#  >50K.    Married-civ-spouse      Prof-specialty          Husband
#  >50K.    Married-civ-spouse     Exec-managerial          Husband
#  <=50K.        Never-married   Machine-op-inspct        Own-child
#  <=50K.             Divorced     Exec-managerial    Not-in-family
#  <=50K.   Married-civ-spouse     Protective-serv          Husband
#  <=50K.              Widowed               Sales   Other-relative
#  <=50K.        Never-married               Sales    Not-in-family
#  >50K.    Married-civ-spouse      Prof-specialty          Husband
#  <=50K.   Married-civ-spouse        Craft-repair          Husband
#  <=50K.        Never-married        Craft-repair        Own-child
#  <=50K.              Widowed     Farming-fishing    Not-in-family
#  >50K.    Married-civ-spouse      Prof-specialty             Wife
#  <=50K.            Separated     Priv-house-serv    Not-in-family
#  <=50K.        Never-married        Adm-clerical        Unmarried
#  <=50K.             Divorced      Prof-specialty    Not-in-family
#  <=50K.   Married-civ-spouse   Handlers-cleaners          Husband
#  <=50K.   Married-civ-spouse        Adm-clerical          Husband
#  <=50K.   Married-civ-spouse               Sales          Husband
#  <=50K.   Married-civ-spouse        Craft-repair          Husband
#  <=50K.        Never-married       Other-service        Own-child
#  <=50K.             Divorced       Other-service    Not-in-family
#  <=50K.        Never-married      Prof-specialty        Own-child
#  <=50K.             Divorced      Prof-specialty    Not-in-family
#  <=50K.              Widowed                   ?   Other-relative
#  <=50K.   Married-civ-spouse      Prof-specialty          Husband
#  <=50K.             Divorced        Adm-clerical        Own-child
#  >50K.    Married-civ-spouse     Exec-managerial          Husband
#
#                            I        J      K     L   M               N
# O
#  <=50K.                Black     Male      0     0  40   United-States
#  <=50K.                White     Male      0     0  50   United-States
#  >50K.                 White     Male      0     0  40   United-States
#  >50K.                 Black     Male   7688     0  40   United-States
#  <=50K.                White   Female      0     0  30   United-States
#  <=50K.                White     Male      0     0  30   United-States
#  <=50K.                Black     Male      0     0  40   United-States
#  >50K.                 White     Male   3103     0  32   United-States
#  <=50K.                White   Female      0     0  40   United-States
#  <=50K.                White     Male      0     0  10   United-States
#  >50K.                 White     Male   6418     0  40   United-States
#  <=50K.                White     Male      0     0  40   United-States
#  <=50K.                White   Female      0     0  39   United-States
#  <=50K.                White     Male      0     0  35   United-States
#  >50K.                 White     Male   3103     0  48   United-States
#  >50K.                 White     Male      0     0  50   United-States
#  <=50K.                White     Male      0     0  25   United-States
#  <=50K.                White   Female      0     0  30   United-States
#  <=50K.                White   Female      0     0  20   United-States
#  >50K.    Asian-Pac-Islander     Male      0     0  45               ?
#  >50K.                 White     Male      0     0  47   United-States
#  <=50K.                Black   Female      0     0  35   United-States
#  <=50K.                White   Female      0     0   6   United-States
#  <=50K.                White     Male      0     0  43            Peru
#  <=50K.                White     Male      0     0  40   United-States
#  >50K.                 White     Male   7298     0  90   United-States
#  <=50K.                White     Male      0     0  20   United-States
#  <=50K.                Black     Male      0     0  54   United-States
#  <=50K.                White     Male      0     0  35   United-States
#  <=50K.                White     Male      0     0  60   United-States
# ...                      ...      ...    ...   ...  ..             ...
#  <=50K.                White     Male   2936     0  20   United-States
#  >50K.                 White     Male   7688     0  40   United-States
#  <=50K.                White   Female      0  1669  40   United-States
#  >50K.                 White     Male      0     0  50   United-States
#  >50K.                 White     Male      0  1902  50   United-States
#  <=50K.                White     Male      0     0  40   United-States
#  <=50K.                White   Female      0     0  40   United-States
#  <=50K.                White     Male      0     0  40   United-States
#  <=50K.                White   Female      0     0   8   United-States
#  <=50K.                White   Female      0     0  45   United-States
#  >50K.                 White     Male  15024     0  55   United-States
#  <=50K.                White     Male      0     0  40   United-States
#  <=50K.                White     Male      0     0  40   United-States
#  <=50K.                White     Male      0     0  32   United-States
#  >50K.                 White   Female      0     0  40               ?
#  <=50K.                White   Female      0     0  32   United-States
#  <=50K.                Black   Female      0     0  40   United-States
#  <=50K.                White     Male      0     0  36   United-States
#  <=50K.                White     Male      0     0  40   United-States
#  <=50K.                White     Male      0     0  40   United-States
#  <=50K.                White     Male      0     0  48   United-States
#  <=50K.                White     Male      0     0  40   United-States
#  <=50K.                White   Female      0     0  40   United-States
#  <=50K.                White     Male      0     0  40   United-States
#  <=50K.                White     Male      0     0  40   United-States
#  <=50K.                White   Female      0     0  36   United-States
#  <=50K.                Black     Male      0     0  40   United-States
#  <=50K.                White     Male      0     0  50   United-States
#  <=50K.   Asian-Pac-Islander     Male   5455     0  40   United-States
#  >50K.                 White     Male      0     0  60   United-States
#
# [16281 rows x 14 columns]

# %% [markdown]
# #### df[>''].value_counts().plot.bar()

# %%
df.groupby('O').B.value_counts().plot.bar()

# %%
df[df.O='>50K.']
# Out:
#   File "<ipython-input-5-3c5cc30e434f>", line 1
#     df[df.O='>50K.']
#            ^
# SyntaxError: invalid syntax

# %%
df[df['B'].str().isin(['Private'])]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-bdcfa8d7c10d> in <module>()
#       1
# ----> 2 df[df['B'].str().isin(['Private'])]
#
# TypeError: 'StringMethods' object is not callable

# %%
df1=df.loc[df.O.str.contains('<')]

# %%
df2=df1.loc[:,'G']

# %%
df2.value_counts().plot.pie()

# %%
df1=df.loc[df.O.str.contains('<')]
df2=df.loc[df.O.str.contains('>')]
df3=df1.loc[:,'G']
df3.value_counts().plot.bar()
df2.loc[:,'G'].value_counts().plot.bar(bottom=df3.value_counts(),color='Black')

# %%
df1=df.loc[df.O.str.contains('<')]
df2=df.loc[df.O.str.contains('>')]
df3=df1.loc[:,'E']
df3.value_counts().plot.bar()
df2.loc[:,'E'].value_counts().plot.bar(bottom=df3.value_counts(),color='Black')

# %%
df[df.G.str.contains('Exec')].O.value_counts().plot.pie()

# %%
df.groupby('E').G.describe()
# Out:
#    count unique                 top freq
# E
# 1     32     10     Farming-fishing    8
# 2     79     10     Farming-fishing   15
# 3    176     12   Machine-op-inspct   39
# 4    309     14        Craft-repair   56
# 5    242     14        Craft-repair   48
# 6    456     14       Other-service   86
# 7    637     14       Other-service  130
# 8    224     14       Other-service   44
# 9   5283     15        Craft-repair  989
# 10  3587     15        Adm-clerical  577
# 11   679     15        Craft-repair  123
# 12   534     14     Exec-managerial   95
# 13  2670     14      Prof-specialty  738
# 14   934     13      Prof-specialty  458
# 15   258     10      Prof-specialty  215
# 16   181     11      Prof-specialty  129
